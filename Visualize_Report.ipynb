# %% [markdown]
# # Visualize Dakota report data from MongoDB

# %%
# %matplotlib inline

# %%
#import dakota_report library
import dakota_report as dr
import matplotlib.pyplot as plt

# %%
#Load reports based on key values
docs = dr.find_documents({'group':'Genetic_param_study02','method':'vector_parameter_study'})

# %% [markdown]
# The following is the results of a 1D parameter study on each parameter about an approximated GIPL objective function minimum.

# %%
for doc in docs:
    #Grab out data from documents
    out_dat = doc['out_data']
    obj_fn_dat = out_dat['obj_fn']
    for out in out_dat.keys():
        if (out != 'obj_fn'):
            
            print out
            plt.figure()
            plt.plot(out_dat[out],obj_fn_dat)
            plt.xlabel(out)
            #plt.ylabel(obj_fn_dat)
            plt.show()
            #print stats
            print 'Pre-objective: ' + str(doc['obj_fun_pre'])
            print 'Pre-params: ' + str(doc['pre_params'])
            print 'Post-params: '+ str(doc['post_params'])
            print 'Pre-error: ' + str(doc['pre_error'])
            print 'Post-error: ' + str(doc['post_error'])
# Out:
# b4
# Pre-objective: 0.00337368412488
# Pre-params: {u'b4': -0.5020576132}
# Post-params: {u'b4': -0.501053498, u'obj_fn': 0.003245563082}
# Pre-error: {u'b4': 54.95605345679011}
# Post-error: {u'b4': 54.64614135802468}
# b5
# Pre-objective: 0.00661719026652
# Pre-params: {u'b5': -0.0787037037}
# Post-params: {u'obj_fn': 0.003206310331, u'b5': -0.08578703703}
# Pre-error: {u'b5': 27.79476724770642}
# Post-error: {u'b5': 21.296296302752292}
# b6
# Pre-objective: 0.00343048329284
# Pre-params: {u'b6': -0.225}
# Post-params: {u'obj_fn': 0.003373684125, u'b6': -0.2475}
# Pre-error: {u'b6': 4.651162790697678}
# Post-error: {u'b6': 15.116279069767444}
# b1
# Pre-objective: 0.00337368412488
# Pre-params: {u'b1': -0.1212962963}
# Post-params: {u'obj_fn': 0.003226049183, u'b1': -0.1096518519}
# Pre-error: {u'b1': 36.159844052631584}
# Post-error: {u'b1': 42.288499}
# b2
# Pre-objective: 0.00325768776636
# Pre-params: {u'b2': -0.9345679012}
# Post-params: {u'obj_fn': 0.003211508816, u'b2': -0.8971851852}
# Pre-error: {u'b2': 3.840877911111108}
# Post-error: {u'b2': 0.312757200000001}
# b3
# Pre-objective: 0.00359480738152
# Pre-params: {u'b3': -0.4617283951}
# Post-params: {u'obj_fn': 0.003233431237, u'b3': -0.4672691358}
# Pre-error: {u'b3': 23.045267483333326}
# Post-error: {u'b3': 22.121810699999994}
# kt4
# Pre-objective: 0.00483268053338
# Pre-params: {u'kt4': 1.202469136}
# Post-params: {u'kt4': 1.207279013, u'obj_fn': 0.003254994444}
# Pre-error: {u'kt4': 15.319074929577464}
# Post-error: {u'kt4': 14.980351197183097}
# kt5
# Pre-objective: 0.00423342111507
# Pre-params: {u'kt5': 1.616666667}
# Post-params: {u'obj_fn': 0.003261237067, u'kt5': 1.4744}
# Pre-error: {u'kt5': 9.176029943820224}
# Post-error: {u'kt5': 17.1685393258427}
# kt6
# Pre-objective: 0.00335790214817
# Pre-params: {u'kt6': 2.202469136}
# Post-params: {u'obj_fn': 0.003373324875, u'kt6': 1.982222222}
# Pre-error: {u'kt6': 10.10330057142858}
# Post-error: {u'kt6': 19.092970530612245}
# kt1
# Pre-objective: 0.00337403840435
# Pre-params: {u'kt1': 1.022777778}
# Post-params: {u'obj_fn': 0.003373684125, u'kt1': 1.022777778}
# Pre-error: {u'kt1': 2.4997351763584277}
# Post-error: {u'kt1': 2.4997351763584277}
# kt2
# Pre-objective: 0.0479948529032
# Pre-params: {u'kt2': 0.7308641975}
# Post-params: {u'obj_fn': 0.001286946513, u'kt2': 0.7703308642}
# Pre-error: {u'kt2': 9.992093903940894}
# Post-error: {u'kt2': 5.13166697044336}
# kt3
# Pre-objective: 0.00440859683243
# Pre-params: {u'kt3': 1.041975309}
# Post-params: {u'obj_fn': 0.003211327979, u'kt3': 1.056562963}
# Pre-error: {u'kt3': 13.886338099173559}
# Post-error: {u'kt3': 12.680746859504133}
# kf6
# Pre-objective: 0.00628290727337
# Pre-params: {u'kf6': 2.585185185}
# Post-params: {u'kf6': 2.326666666, u'obj_fn': 0.003373684125}
# Pre-error: {u'kf6': 1.328809732824438}
# Post-error: {u'kf6': 11.19592877862596}
# kf4
# Pre-objective: 0.00337368412488
# Pre-params: {u'kf4': 2.547222222}
# Post-params: {u'obj_fn': 0.003373684125, u'kf4': 2.547222222}
# Pre-error: {u'kf4': 1.0802469047618966}
# Post-error: {u'kf4': 1.0802469047618966}
# kf5
# Pre-objective: 0.128534097776
# Pre-params: {u'kf5': 2.016666667}
# Post-params: {u'obj_fn': 0.003276080991, u'kf5': 2.012633334}
# Pre-error: {u'kf5': 1.1437908333333366}
# Post-error: {u'kf5': 1.3415032352941085}
# kf2
# Pre-objective: 0.00660133145197
# Pre-params: {u'kf2': 2.038888889}
# Post-params: {u'obj_fn': 0.003277245793, u'kf2': 2.063355556}
# Pre-error: {u'kf2': 0.43787630541872247}
# Post-error: {u'kf2': 1.6431308374384268}
# kf3
# Pre-objective: 0.00559156339997
# Pre-params: {u'kf3': 2.17962963}
# Post-params: {u'obj_fn': 0.003213052401, u'kf3': 2.188348149}
# Pre-error: {u'kf3': 2.330029577464793}
# Post-error: {u'kf3': 2.739349718309857}
# kf1
# Pre-objective: 0.0226230145221
# Pre-params: {u'kf1': 2.016666667}
# Post-params: {u'obj_fn': 0.003248066807, u'kf1': 2.004566667}
# Pre-error: {u'kf1': 1.6260162439024322}
# Post-error: {u'kf1': 2.2162601463414457}
# a1
# Pre-objective: 0.00941075156916
# Pre-params: {u'a1': 0.05222222222}
# Post-params: {u'a1': 0.05431111111, u'obj_fn': 0.003236563434}
# Pre-error: {u'a1': 25.3968254}
# Post-error: {u'a1': 22.412698414285725}
# a3
# Pre-objective: 0.00325534597416
# Pre-params: {u'a3': 0.06}
# Post-params: {u'obj_fn': 0.003292319749, u'a3': 0.05976}
# Pre-error: {u'a3': 0.0}
# Post-error: {u'a3': 0.3999999999999953}
# a2
# Pre-objective: 0.00543295382411
# Pre-params: {u'a2': 0.001}
# Post-params: {u'obj_fn': 0.003218315667, u'a2': 0.00091}
# Pre-error: {u'a2': 0.0}
# Post-error: {u'a2': 9.000000000000002}
# a5
# Pre-objective: 0.0032394433139
# Pre-params: {u'a5': 0.0225}
# Post-params: {u'obj_fn': 0.003170307913, u'a5': 0.024705}
# Pre-error: {u'a5': 25.000000000000007}
# Post-error: {u'a5': 37.250000000000014}
# a4
# Pre-objective: 0.0031701242407
# Pre-params: {u'a4': 0.06}
# Post-params: {u'obj_fn': 0.003299002846, u'a4': 0.05988}
# Pre-error: {u'a4': 0.0}
# Post-error: {u'a4': 0.19999999999999185}
# a6
# Pre-objective: 0.0504934695963
# Pre-params: {u'a6': 0.0675}
# Post-params: {u'obj_fn': 0.003373684125, u'a6': 0.063855}
# Pre-error: {u'a6': 0.7462686567164185}
# Post-error: {u'a6': 4.694029850746281}
# b4
# Pre-objective: 0.00337368412488
# Pre-params: {u'b4': -0.5020576132}
# Post-params: {u'b4': -0.501053498, u'obj_fn': 0.003245563082}
# Pre-error: {u'b4': 54.95605345679011}
# Post-error: {u'b4': 54.64614135802468}
# b5
# Pre-objective: 0.00661719026652
# Pre-params: {u'b5': -0.0787037037}
# Post-params: {u'obj_fn': 0.003206310331, u'b5': -0.08578703703}
# Pre-error: {u'b5': 27.79476724770642}
# Post-error: {u'b5': 21.296296302752292}
# b6
# Pre-objective: 0.00343048329284
# Pre-params: {u'b6': -0.225}
# Post-params: {u'obj_fn': 0.003373684125, u'b6': -0.2475}
# Pre-error: {u'b6': 4.651162790697678}
# Post-error: {u'b6': 15.116279069767444}
# b1
# Pre-objective: 0.00337368412488
# Pre-params: {u'b1': -0.1212962963}
# Post-params: {u'obj_fn': 0.003226049183, u'b1': -0.1096518519}
# Pre-error: {u'b1': 36.159844052631584}
# Post-error: {u'b1': 42.288499}
# b2
# Pre-objective: 0.00325768776636
# Pre-params: {u'b2': -0.9345679012}
# Post-params: {u'obj_fn': 0.003211508816, u'b2': -0.8971851852}
# Pre-error: {u'b2': 3.840877911111108}
# Post-error: {u'b2': 0.312757200000001}
# b3
# Pre-objective: 0.00359480738152
# Pre-params: {u'b3': -0.4617283951}
# Post-params: {u'obj_fn': 0.003233431237, u'b3': -0.4672691358}
# Pre-error: {u'b3': 23.045267483333326}
# Post-error: {u'b3': 22.121810699999994}
# kt4
# Pre-objective: 0.00483268053338
# Pre-params: {u'kt4': 1.202469136}
# Post-params: {u'kt4': 1.207279013, u'obj_fn': 0.003254994444}
# Pre-error: {u'kt4': 15.319074929577464}
# Post-error: {u'kt4': 14.980351197183097}
# kt5
# Pre-objective: 0.00423342111507
# Pre-params: {u'kt5': 1.616666667}
# Post-params: {u'obj_fn': 0.003261237067, u'kt5': 1.4744}
# Pre-error: {u'kt5': 9.176029943820224}
# Post-error: {u'kt5': 17.1685393258427}
# kt6
# Pre-objective: 0.00335790214817
# Pre-params: {u'kt6': 2.202469136}
# Post-params: {u'obj_fn': 0.003373324875, u'kt6': 1.982222222}
# Pre-error: {u'kt6': 10.10330057142858}
# Post-error: {u'kt6': 19.092970530612245}
# kt1
# Pre-objective: 0.00337403840435
# Pre-params: {u'kt1': 1.022777778}
# Post-params: {u'obj_fn': 0.003373684125, u'kt1': 1.022777778}
# Pre-error: {u'kt1': 2.4997351763584277}
# Post-error: {u'kt1': 2.4997351763584277}
# kt2
# Pre-objective: 0.0479948529032
# Pre-params: {u'kt2': 0.7308641975}
# Post-params: {u'obj_fn': 0.001286946513, u'kt2': 0.7703308642}
# Pre-error: {u'kt2': 9.992093903940894}
# Post-error: {u'kt2': 5.13166697044336}
# kt3
# Pre-objective: 0.00440859683243
# Pre-params: {u'kt3': 1.041975309}
# Post-params: {u'obj_fn': 0.003211327979, u'kt3': 1.056562963}
# Pre-error: {u'kt3': 13.886338099173559}
# Post-error: {u'kt3': 12.680746859504133}
# kf6
# Pre-objective: 0.00628290727337
# Pre-params: {u'kf6': 2.585185185}
# Post-params: {u'kf6': 2.326666666, u'obj_fn': 0.003373684125}
# Pre-error: {u'kf6': 1.328809732824438}
# Post-error: {u'kf6': 11.19592877862596}
# kf4
# Pre-objective: 0.00337368412488
# Pre-params: {u'kf4': 2.547222222}
# Post-params: {u'obj_fn': 0.003373684125, u'kf4': 2.547222222}
# Pre-error: {u'kf4': 1.0802469047618966}
# Post-error: {u'kf4': 1.0802469047618966}
# kf5
# Pre-objective: 0.128534097776
# Pre-params: {u'kf5': 2.016666667}
# Post-params: {u'obj_fn': 0.003276080991, u'kf5': 2.012633334}
# Pre-error: {u'kf5': 1.1437908333333366}
# Post-error: {u'kf5': 1.3415032352941085}
# kf2
# Pre-objective: 0.00660133145197
# Pre-params: {u'kf2': 2.038888889}
# Post-params: {u'obj_fn': 0.003277245793, u'kf2': 2.063355556}
# Pre-error: {u'kf2': 0.43787630541872247}
# Post-error: {u'kf2': 1.6431308374384268}
# kf3
# Pre-objective: 0.00559156339997
# Pre-params: {u'kf3': 2.17962963}
# Post-params: {u'obj_fn': 0.003213052401, u'kf3': 2.188348149}
# Pre-error: {u'kf3': 2.330029577464793}
# Post-error: {u'kf3': 2.739349718309857}
# kf1
# Pre-objective: 0.0226230145221
# Pre-params: {u'kf1': 2.016666667}
# Post-params: {u'obj_fn': 0.003248066807, u'kf1': 2.004566667}
# Pre-error: {u'kf1': 1.6260162439024322}
# Post-error: {u'kf1': 2.2162601463414457}
# a1
# Pre-objective: 0.00941075156916
# Pre-params: {u'a1': 0.05222222222}
# Post-params: {u'a1': 0.05431111111, u'obj_fn': 0.003236563434}
# Pre-error: {u'a1': 25.3968254}
# Post-error: {u'a1': 22.412698414285725}
# a3
# Pre-objective: 0.00325534597416
# Pre-params: {u'a3': 0.06}
# Post-params: {u'obj_fn': 0.003292319749, u'a3': 0.05976}
# Pre-error: {u'a3': 0.0}
# Post-error: {u'a3': 0.3999999999999953}
# a2
# Pre-objective: 0.00543295382411
# Pre-params: {u'a2': 0.001}
# Post-params: {u'obj_fn': 0.003218315667, u'a2': 0.00091}
# Pre-error: {u'a2': 0.0}
# Post-error: {u'a2': 9.000000000000002}
# a5
# Pre-objective: 0.0032394433139
# Pre-params: {u'a5': 0.0225}
# Post-params: {u'obj_fn': 0.003170307913, u'a5': 0.024705}
# Pre-error: {u'a5': 25.000000000000007}
# Post-error: {u'a5': 37.250000000000014}
# a4
# Pre-objective: 0.0031701242407
# Pre-params: {u'a4': 0.06}
# Post-params: {u'obj_fn': 0.003299002846, u'a4': 0.05988}
# Pre-error: {u'a4': 0.0}
# Post-error: {u'a4': 0.19999999999999185}
# a6
# Pre-objective: 0.0504934695963
# Pre-params: {u'a6': 0.0675}
# Post-params: {u'obj_fn': 0.003373684125, u'a6': 0.063855}
# Pre-error: {u'a6': 0.7462686567164185}
# Post-error: {u'a6': 4.694029850746281}

# %%
docs
